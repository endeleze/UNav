# %%
import h5py

# %%
h5_fn = "/home/nattachart.tak/Data/experiments/Mapping/data/unav2-data/Mahidol_University/ICT/1.1_NetVlad/features/global_features_NetVlad.h5"

# %%
h5_fn = "/home/nattachart.tak/Data/experiments/Mapping/data/unav2-data/Mahidol_University/ICT/1.1_NetVlad/features/local_features.h5"

# %%
h5_fn = "/home/nattachart.tak/Data/experiments/Mapping/data/unav2-data/Mahidol_University/ICT/1.1_CricaVPR/features/local_features.h5"

# %%
h5_fn = "/home/nattachart.tak/Data/experiments/Mapping/data/unav2-data/Mahidol_University/ICT/1.1_DinoV2Salad/features/local_features.h5"

# %%
f = h5py.File(h5_fn, 'r')

# %%
list(f.keys())
# Out:
# ['000000_pitch00_yaw00.png',
#  '000000_pitch00_yaw01.png',
#  '000000_pitch00_yaw02.png',
#  '000000_pitch00_yaw03.png',
#  '000000_pitch00_yaw04.png',
#  '000000_pitch00_yaw05.png',
#  '000000_pitch00_yaw06.png',
#  '000000_pitch00_yaw07.png',
#  '000000_pitch00_yaw08.png',
#  '000000_pitch00_yaw09.png',
#  '000000_pitch00_yaw10.png',
#  '000000_pitch00_yaw11.png',
#  '000000_pitch00_yaw12.png',
#  '000000_pitch00_yaw13.png',
#  '000000_pitch00_yaw14.png',
#  '000000_pitch00_yaw15.png',
#  '000000_pitch00_yaw16.png',
#  '000000_pitch00_yaw17.png',
#  '000001_pitch00_yaw00.png',
#  '000001_pitch00_yaw01.png',
#  '000001_pitch00_yaw02.png',
#  '000001_pitch00_yaw03.png',
#  '000001_pitch00_yaw04.png',
#  '000001_pitch00_yaw05.png',
#  '000001_pitch00_yaw06.png',
#  '000001_pitch00_yaw07.png',
#  '000001_pitch00_yaw08.png',
#  '000001_pitch00_yaw09.png',
#  '000001_pitch00_yaw10.png',
#  '000001_pitch00_yaw11.png',
#  '000001_pitch00_yaw12.png',
#  '000001_pitch00_yaw13.png',
# ...
