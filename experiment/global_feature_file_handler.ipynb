# %%
import h5py

# %%
gf_netvlad = '/home/nattachart.tak/Data/experiments/Mapping/data/unav2-data/Mahidol_University/ICT/1.1_NetVlad/features/global_features_NetVlad.h5'
gf_cricavpr = '/home/nattachart.tak/Data/experiments/Mapping/data/unav2-data/Mahidol_University/ICT/1.1_CricaVPR/features/global_features_CricaVPR.h5'
gf_mixedvpr = '/home/nattachart.tak/Data/experiments/Mapping/data/unav2-data/Mahidol_University/ICT/1.1_MixVPR/features/global_features_MixVPR.h5'

# %%
k = '000000_pitch00_yaw00.png'
with h5py.File(gf_mixedvpr, 'r') as f:
    print("", f[k][:].shape)
    print("", f[k])
    print(len(f.keys()))
    print(type(f.keys()))
    print(f.name)
# Out:
#  (4096,)
#  <HDF5 dataset "000000_pitch00_yaw00.png": shape (4096,), type "<f4">
# 6030
# <class 'h5py._hl.base.KeysViewHDF5'>
# /
